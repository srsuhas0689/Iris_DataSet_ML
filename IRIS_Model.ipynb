# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
filepath = "C:\\Users\\Dell\\OneDrive - bjoz\\Desktop\\Machine Learning\\Data Set\\iris\\iris.csv"

# %%
df = pd.read_csv(filepath)

# %%
df.columns = ["sepal_length","sepal_width","petal_length","petal_width","target"]

# %%
df.tail()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width          target
# 144           6.7          3.0           5.2          2.3  Iris-virginica
# 145           6.3          2.5           5.0          1.9  Iris-virginica
# 146           6.5          3.0           5.2          2.0  Iris-virginica
# 147           6.2          3.4           5.4          2.3  Iris-virginica
# 148           5.9          3.0           5.1          1.8  Iris-virginica

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width          target
# 0             4.9          3.0           1.4          0.2     Iris-setosa
# 1             4.7          3.2           1.3          0.2     Iris-setosa
# 2             4.6          3.1           1.5          0.2     Iris-setosa
# 3             5.0          3.6           1.4          0.2     Iris-setosa
# 4             5.4          3.9           1.7          0.4     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 144           6.7          3.0           5.2          2.3  Iris-virginica
# 145           6.3          2.5           5.0          1.9  Iris-virginica
# 146           6.5          3.0           5.2          2.0  Iris-virginica
# 147           6.2          3.4           5.4          2.3  Iris-virginica
# 148           5.9          3.0           5.1          1.8  Iris-virginica
#
# [149 rows x 5 columns]

# %%
df.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width', 'target'], dtype='object')

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width       target
# 0           4.9          3.0           1.4          0.2  Iris-setosa
# 1           4.7          3.2           1.3          0.2  Iris-setosa
# 2           4.6          3.1           1.5          0.2  Iris-setosa
# 3           5.0          3.6           1.4          0.2  Iris-setosa
# 4           5.4          3.9           1.7          0.4  Iris-setosa

# %%
df.target.replace({"Iris-setosa":"setosa","Iris-versicolor":"versicolor","Iris-virginica":"virginica"})
# Out:
# 0         setosa
# 1         setosa
# 2         setosa
# 3         setosa
# 4         setosa
#          ...
# 144    virginica
# 145    virginica
# 146    virginica
# 147    virginica
# 148    virginica
# Name: target, Length: 149, dtype: object

# %%
df.target.unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
df.target.replace({"Iris-setosa":"setosa","Iris-versicolor":"versicolor","Iris-virginica":"virginica"},inplace=True)

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width  target
# 0           4.9          3.0           1.4          0.2  setosa
# 1           4.7          3.2           1.3          0.2  setosa
# 2           4.6          3.1           1.5          0.2  setosa
# 3           5.0          3.6           1.4          0.2  setosa
# 4           5.4          3.9           1.7          0.4  setosa

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 149 entries, 0 to 148
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  149 non-null    float64
#  1   sepal_width   149 non-null    float64
#  2   petal_length  149 non-null    float64
#  3   petal_width   149 non-null    float64
#  4   target        149 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 5.9+ KB

# %%
df.target.replace({""})
# Out:
# 0         setosa
# 1         setosa
# 2         setosa
# 3         setosa
# 4         setosa
#          ...
# 144    virginica
# 145    virginica
# 146    virginica
# 147    virginica
# 148    virginica
# Name: target, Length: 149, dtype: object

# %% [markdown]
# EDA

# %%
df.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    149.000000   149.000000    149.000000   149.000000
# mean       5.848322     3.051007      3.774497     1.205369
# std        0.828594     0.433499      1.759651     0.761292
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.400000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
df.corr()
# Out:
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      1.000000    -0.103784      0.871283     0.816971
# sepal_width      -0.103784     1.000000     -0.415218    -0.350733
# petal_length      0.871283    -0.415218      1.000000     0.962314
# petal_width       0.816971    -0.350733      0.962314     1.000000

# %%
df.target.value_counts()
# Out:
# versicolor    50
# virginica     50
# setosa        49
# Name: target, dtype: int64

# %% [markdown]
# # 2D Scatterplot

# %%
sns.FacetGrid(df,hue="target",size=6).map(plt.scatter,"sepal_length","sepal_width").add_legend()
# Out:
# C:\Users\Dell\anaconda\lib\site-packages\seaborn\axisgrid.py:337: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
sns.FacetGrid(df,hue="target",height=6).map(plt.scatter,"sepal_length","sepal_width").add_legend()

# %% [markdown]
# # Pairplot

# %%
sns.pairplot(df,hue="target")

# %%
plt.show()

# %% [markdown]
# # Histogram

# %%
plt.hist(df["sepal_length"],bins=25);

# %%
sns.FacetGrid(df, hue="target", size=8).map(sns.distplot)
# Out:
# C:\Users\Dell\anaconda\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Dell\anaconda\lib\site-packages\numpy\lib\histograms.py:906: RuntimeWarning: invalid value encountered in true_divide
#   return n/db/n.sum(), bin_edges
# C:\Users\Dell\anaconda\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
plt.show()

# %%
sns.FacetGrid(df, hue="target", height=8).map(sns.distplot, "petal_width").add_legend()
# Out:
# C:\Users\Dell\anaconda\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Dell\anaconda\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
plt.show()

# %%
sns.FacetGrid(df, hue="target", height=8).map(sns.distplot, "petal_length").add_legend()
# Out:
# C:\Users\Dell\anaconda\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Dell\anaconda\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
plt.show()

# %%
sns.FacetGrid(df, hue="target", height=8).map(sns.distplot, "sepal_width").add_legend()
# Out:
# C:\Users\Dell\anaconda\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Dell\anaconda\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
plt.show()

# %%
sns.FacetGrid(df, hue="target", height=8).map(sns.distplot, "sepal_length").add_legend()
# Out:
# C:\Users\Dell\anaconda\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Dell\anaconda\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
plt.show()

# %% [markdown]
# # Box plot

# %%
sns.boxplot(x="target",y="petal_length",data=df)
plt.show()

# %%
plt.show()
